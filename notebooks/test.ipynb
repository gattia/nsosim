# %%
from nsosim.utils import load_model

# %%
dict_bones ={
            'femur': {
                'ref': {
                    'folder': os.path.join(folder_ref_recons, 'femur'),
                    'bone_filename': 'smith2019-R-femur-bone_processed.vtk'
                },
                'subject': {
                    'folder': folder_subject_bones,
                    'bone_filename':f'{subject_id}_{side}_femur.vtk',
                    'cart_filename': f'{subject_id}_{side}_femur_cart.vtk',
                    'med_men_filename': f'{subject_id}_{side}_med_men.vtk',
                    'lat_men_filename': f'{subject_id}_{side}_lat_men.vtk',
                },
                'model': {
                    'path_model_state': os.path.join(folder_nsm_models, '568_nsm_femur_bone_cart_men_v0.0.1', 'model', '2000.pth'),
                    'path_model_config': os.path.join(folder_nsm_models, '568_nsm_femur_bone_cart_men_v0.0.1', 'model_params_config.json')
                },
                'wrap':{
                    'path_labeled_bone': os.path.join(folder_labeled_bone, 'femur_labeled.vtk'),
                }
                    
            },
            'tibia': {
                'ref': {
                    'folder': os.path.join(folder_ref_recons, 'tibia'),
                    'bone_filename': 'smith2019-R-tibia-bone_processed.vtk'
                },
                'subject': {
                    'folder': folder_subject_bones,
                    'bone_filename':f'{subject_id}_{side}_tibia.vtk',
                    'cart_filename': f'{subject_id}_{side}_tibia_cart.vtk'
                },
                'model': {
                    'path_model_state': os.path.join(folder_nsm_models, '650_nsm_tibia_v0.0.1', 'model', '2000.pth'),
                    'path_model_config': os.path.join(folder_nsm_models, '650_nsm_tibia_v0.0.1', 'model_params_config.json')
                },
                'wrap':{
                    'path_labeled_bone': os.path.join(folder_labeled_bone, 'tibia_labeled.vtk'),
                }
            },
            'patella': {
                'ref': {
                    'folder': os.path.join(folder_ref_recons, 'patella'),
                    'bone_filename': 'smith2019-R-patella-bone_processed.vtk'
                },
                'subject': {
                    'folder': folder_subject_bones,
                    'bone_filename':f'{subject_id}_{side}_patella.vtk',
                    'cart_filename': f'{subject_id}_{side}_patella_cart.vtk'
                },
                'model': {
                    'path_model_state': os.path.join(folder_nsm_models, '648_nsm_patella_v0.0.1', 'model', '2000.pth'),
                    'path_model_config': os.path.join(folder_nsm_models, '648_nsm_patella_v0.0.1', 'model_params_config.json')
                },
                'wrap':{
                    'path_labeled_bone': os.path.join(folder_labeled_bone, 'patella_labeled.vtk'),
                }
            },
            'meniscus': {
                'ref': {
                    'folder': os.path.join(folder_labeled_bone, 'menisci'),
                    'med_men_filename': 'med_meniscus_processed.vtk',
                    'lat_men_filename': 'lat_meniscus_processed.vtk'
                }
            }
        }
